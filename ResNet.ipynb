# %% [markdown]
# # Residual Networks (ResNet) – Deep Learning

# %%
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# %%
batch_size = 32
epochs = 200
data_augmentation = True
num_classes = 10
subtract_pixel_mean = True
n = 3
version = 1

if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

model_type = 'ResNet % dv % d' % (depth, version)

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

input_shape = x_train.shape[1:]

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 105s 1us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate:', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)

    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10): 
    if (depth - 2) % 6 != 0: 
        raise ValueError('depth should be 6n + 2 (eg 20, 32, 44 in [a])') 

    num_filters = 16
    num_res_blocks = int((depth - 2) / 6) 

    inputs = Input(shape=input_shape) 
    x = resnet_layer(inputs=inputs) 

    for stack in range(3): 
        for res_block in range(num_res_blocks): 
            strides = 1
            if stack > 0 and res_block == 0: 
                strides = 2 
            y = resnet_layer(inputs=x, 
                             num_filters=num_filters, 
                             strides=strides) 
            y = resnet_layer(inputs=y, 
                             num_filters=num_filters, 
                             activation=None) 
            if stack > 0 and res_block == 0: 
                x = resnet_layer(inputs=x, 
                                 num_filters=num_filters, 
                                 kernel_size=1, 
                                 strides=strides, 
                                 activation=None, 
                                 batch_normalization=False) 
            x = keras.layers.add([x, y]) 
            x = Activation('relu')(x) 
        num_filters *= 2

    x = AveragePooling2D(pool_size=8)(x) 
    y = Flatten()(x) 
    outputs = Dense(num_classes, 
                    activation='softmax', 
                    kernel_initializer='he_normal')(y) 

    model = Model(inputs=inputs, outputs=outputs) 
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n + 2 (eg 56 or 110 in [b])')

    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:
                    strides = 2

            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2: 
    model = resnet_v2(input_shape=input_shape, depth=depth) 
else: 
    model = resnet_v1(input_shape=input_shape, depth=depth) 

model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(learning_rate=lr_schedule(0)), 
              metrics=['accuracy']) 
model.summary() 
print(model_type)

save_dir = os.path.join(os.getcwd(), 'saved_models') 
model_name = 'cifar10_%s_model.{epoch:03d}.keras' % model_type 
if not os.path.isdir(save_dir): 
    os.makedirs(save_dir) 
filepath = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(filepath=filepath, 
                              monitor='val_acc', 
                              verbose=1, 
                              save_best_only=True) 

lr_scheduler = LearningRateScheduler(lr_schedule) 

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1), 
                               cooldown=0, 
                               patience=5, 
                               min_lr=0.5e-6) 

callbacks = [checkpoint, lr_reducer, lr_scheduler] 

if not data_augmentation: 
    print('Not using data augmentation.') 
    model.fit(x_train, y_train, 
              batch_size=batch_size, 
              epochs=epochs, 
              validation_data=(x_test, y_test), 
              shuffle=True, 
              callbacks=callbacks) 
else: 
    print('Using real-time data augmentation.') 
    datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True
    )

    datagen.fit(x_train)

    model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
              epochs=epochs,
              validation_data=(x_test, y_test),
              callbacks=callbacks)
# Out:
# Learning rate: 0.001
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 16)           448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 16)           64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 16)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)           2320      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 16)           64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 32, 16)           64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 32, 32, 16)           0         ['activation[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 32, 32, 16)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32, 16)           64        ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 32, 32, 16)           64        ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 32, 32, 16)           0         ['activation_2[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 32, 32, 16)           0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 16)           64        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 16)           2320      ['activation_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 32, 32, 16)           0         ['activation_4[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 32, 32, 16)           0         ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 32)           4640      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 16, 32)           128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 32)           9248      ['activation_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 32)           544       ['activation_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 32)           128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 16, 16, 32)           0         ['conv2d_9[0][0]',
#                                                                      'batch_normalization_8[0][0]'
#                                                                     ]
#
#  activation_8 (Activation)   (None, 16, 16, 32)           0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 16, 16, 32)           128       ['conv2d_10[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 32)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 32)           128       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 32)           0         ['activation_8[0][0]',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_10 (Activation)  (None, 16, 16, 32)           0         ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 32)           128       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 32)           9248      ['activation_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 32)           128       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 32)           0         ['activation_10[0][0]',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 16, 16, 32)           0         ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 64)             18496     ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 64)             256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_13[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 64)             2112      ['activation_12[0][0]']
#
#  batch_normalization_14 (Ba  (None, 8, 8, 64)             256       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 8, 8, 64)             0         ['conv2d_16[0][0]',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 8, 8, 64)             0         ['add_6[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 8, 8, 64)             256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 8, 8, 64)             256       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 8, 8, 64)             0         ['activation_14[0][0]',
#                                                                      'batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 8, 8, 64)             0         ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 8, 8, 64)             256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 8, 8, 64)             0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 64)             36928     ['activation_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 8, 8, 64)             256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 8, 8, 64)             0         ['activation_16[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 8, 8, 64)             0         ['add_8[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 64)             0         ['activation_18[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 64)                   0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 10)                   650       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 274442 (1.05 MB)
# Trainable params: 273066 (1.04 MB)
# Non-trainable params: 1376 (5.38 KB)
# __________________________________________________________________________________________________
# ResNet  20v  1
# Using real-time data augmentation.
# Learning rate: 0.001
# Epoch 1/200
# 1563/1563 [==============================] - ETA: 0s - loss: 1.6177 - accuracy: 0.4675WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 164s 103ms/step - loss: 1.6177 - accuracy: 0.4675 - val_loss: 1.4613 - val_accuracy: 0.5328 - lr: 0.0010
# Learning rate: 0.001
# Epoch 2/200
# 1563/1563 [==============================] - ETA: 0s - loss: 1.2395 - accuracy: 0.6140WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 152s 97ms/step - loss: 1.2395 - accuracy: 0.6140 - val_loss: 1.6108 - val_accuracy: 0.5376 - lr: 0.0010
# Learning rate: 0.001
# Epoch 3/200
# 1563/1563 [==============================] - ETA: 0s - loss: 1.0753 - accuracy: 0.6775WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 155s 99ms/step - loss: 1.0753 - accuracy: 0.6775 - val_loss: 1.0370 - val_accuracy: 0.7020 - lr: 0.0010
# Learning rate: 0.001
# Epoch 4/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9760 - accuracy: 0.7174WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 166s 107ms/step - loss: 0.9760 - accuracy: 0.7174 - val_loss: 1.3125 - val_accuracy: 0.6317 - lr: 0.0010
# Learning rate: 0.001
# Epoch 5/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.9160 - accuracy: 0.7381WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 162s 104ms/step - loss: 0.9160 - accuracy: 0.7381 - val_loss: 1.1043 - val_accuracy: 0.6956 - lr: 0.0010
# Learning rate: 0.001
# Epoch 6/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.7561WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 161s 103ms/step - loss: 0.8697 - accuracy: 0.7561 - val_loss: 1.1944 - val_accuracy: 0.6662 - lr: 0.0010
# Learning rate: 0.001
# Epoch 7/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.
- lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 165/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9652WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.2238 - accuracy: 0.9652 - val_loss: 0.4150 - val_accuracy: 0.9142 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 166/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9666WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.2226 - accuracy: 0.9666 - val_loss: 0.4170 - val_accuracy: 0.9132 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 167/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9662WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.2230 - accuracy: 0.9662 - val_loss: 0.4164 - val_accuracy: 0.9137 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 168/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.2233 - accuracy: 0.9670 - val_loss: 0.4190 - val_accuracy: 0.9127 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 169/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9659WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.2239 - accuracy: 0.9659 - val_loss: 0.4188 - val_accuracy: 0.9127 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 170/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.2206 - accuracy: 0.9670 - val_loss: 0.4173 - val_accuracy: 0.9138 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 171/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9653WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.2242 - accuracy: 0.9653 - val_loss: 0.4179 - val_accuracy: 0.9132 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 172/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9669WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 101ms/step - loss: 0.2219 - accuracy: 0.9669 - val_loss: 0.4138 - val_accuracy: 0.9133 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 173/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9648WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2253 - accuracy: 0.9648 - val_loss: 0.4155 - val_accuracy: 0.9140 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 174/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9655WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.2236 - accuracy: 0.9655 - val_loss: 0.4161 - val_accuracy: 0.9135 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 175/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9672WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 158s 101ms/step - loss: 0.2200 - accuracy: 0.9672 - val_loss: 0.4151 - val_accuracy: 0.9133 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 176/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9659WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 155s 99ms/step - loss: 0.2230 - accuracy: 0.9659 - val_loss: 0.4179 - val_accuracy: 0.9133 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 177/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2192 - accuracy: 0.9680WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.2192 - accuracy: 0.9680 - val_loss: 0.4196 - val_accuracy: 0.9123 - lr: 5.0000e-07
# Learning rate: 1e-06
# Epoch 178/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9678WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2219 - accuracy: 0.9678 - val_loss: 0.4145 - val_accuracy: 0.9137 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 179/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2222 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 101ms/step - loss: 0.2222 - accuracy: 0.9656 - val_loss: 0.4161 - val_accuracy: 0.9138 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 180/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9659WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2239 - accuracy: 0.9659 - val_loss: 0.4179 - val_accuracy: 0.9129 - lr: 1.0000e-06
# Learning rate: 1e-06
# Epoch 181/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9663WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2215 - accuracy: 0.9663 - val_loss: 0.4157 - val_accuracy: 0.9136 - lr: 1.0000e-06
# Learning rate: 5e-07
# Epoch 182/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9663WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2235 - accuracy: 0.9663 - val_loss: 0.4175 - val_accuracy: 0.9135 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 183/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9665WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.2217 - accuracy: 0.9665 - val_loss: 0.4167 - val_accuracy: 0.9137 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 184/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2215 - accuracy: 0.9671WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.2215 - accuracy: 0.9671 - val_loss: 0.4154 - val_accuracy: 0.9143 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 185/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9660WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2226 - accuracy: 0.9660 - val_loss: 0.4168 - val_accuracy: 0.9141 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 186/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9670WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2208 - accuracy: 0.9670 - val_loss: 0.4181 - val_accuracy: 0.9136 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 187/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9663WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.2214 - accuracy: 0.9663 - val_loss: 0.4169 - val_accuracy: 0.9135 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 188/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2202 - accuracy: 0.9669WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.2202 - accuracy: 0.9669 - val_loss: 0.4173 - val_accuracy: 0.9134 - lr: 5.0000e-07
# Learning rate: 5e-07
# Epoch 189/200
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2220 - accuracy: 0.9668

# %%
from tensorflow.keras.models import load_model

# Load the trained model
model_path = "saved_models/cifar10_resnet_model.XXX.keras"  # Change XXX to the best epoch number
model = load_model(model_path)

# Print model summary to confirm loading
model.summary()

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

# %%
import numpy as np

# Get predictions for the test set
predictions = model.predict(x_test)

# Convert softmax output to class labels
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Print first 10 predictions
print("Predicted:", predicted_classes[:10])
print("Actual   :", true_classes[:10])
